# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0 pyspark-shell'

# home
#hostip = "192.168.1.101" 


# library
hostip = '10.192.0.143'

from pyspark.sql import SparkSession
import pyspark.sql.functions as F

import pymongo
from pymongo import MongoClient

# %%
# import statements
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random
import pandas as pd
import datetime as dt
from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, element_at, when
import pygeohash as pgh
import json
from pprint import pprint
import datetime

#Initialize our spark session with 
#threads = #logicalCPU and the given application name.

spark = (
    SparkSession.builder
    .master('local[*]')
    .appName('Spark Streaming from Kafka into MongoDB')
    .getOrCreate()
)

# %%
# Create a streaming dataframe with options 
# providing the bootstrap server(s) and topic name.

topic_stream_df1 = (
    spark.readStream.format('kafka')
    .option('kafka.bootstrap.servers', f'{hostip}:9092')
    .option('subscribe', 'PartB1')
    .option("failOnDataLoss", "false")
    .load()
)

union_stream = topic_stream_df1

stream = union_stream.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# %%
def process_data(batch_df, batch_id):
    
    # print(f"Processing batch: {batch_id}")
    collected_data = batch_df.collect()
    
    # this climate will go to the inside to database
    climate = {}
    
    # initial list for calculating stage
    initial_AQUA = []
    initial_TERA = []

    try:
        if len(collected_data) > 0:
            
            
            for raw in collected_data:
                
                # make json format
                data = raw.asDict()
                data = data['value']
                data = json.loads(data)
                
                
                # data pre processing based on producer
                if data['producer'] == 'producer1':
                    data['latitude'] = float(data['latitude'])
                    data['longitude'] = float(data['longitude'])
                    data['air_temperature_celcius'] = float(data['air_temperature_celcius'])
                    data['relative_humidity'] = float(data['relative_humidity'])
                    data['windspeed_knots'] = float(data['windspeed_knots'])
                    data['max_wind_speed'] = float(data['max_wind_speed'])
                    data['GHI_w/m2'] = float(data['GHI_w/m2'])                                
                    created_time_obj = datetime.datetime.strptime(data['created_time'], "%Y-%m-%dT%H:%M:%S")
                    formatted_time = created_time_obj.strftime("%Y-%m-%d %H:%M:%S")
                    data['created_time'] = formatted_time
                    
                    climate = data
                    
                elif data['producer'] == 'producer2':
                    data['latitude'] = float(data['latitude'])
                    data['longitude'] = float(data['longitude'])
                    data['confidence'] = float(data['confidence'])
                    data['surface_temperature_celcius'] = float(data['surface_temperature_celcius'])
                    created_time_obj = datetime.datetime.strptime(data['created_time'], "%Y-%m-%dT%H:%M:%S")
                    formatted_time = created_time_obj.strftime("%Y-%m-%d %H:%M:%S")
                    data['created_time'] = formatted_time
                    initial_AQUA.append(data)
                    
                else:
                    data['latitude'] = float(data['latitude'])
                    data['longitude'] = float(data['longitude'])
                    data['confidence'] = float(data['confidence'])
                    data['surface_temperature_celcius'] = float(data['surface_temperature_celcius'])
                    created_time_obj = datetime.datetime.strptime(data['created_time'], "%Y-%m-%dT%H:%M:%S")
                    formatted_time = created_time_obj.strftime("%Y-%m-%d %H:%M:%S")
                    data['created_time'] = formatted_time
                    initial_TERA.append(data)
                
                # second stage : geohash (compare climate and initial datas)       
                temp_hotspot = []   

                # Process climate data
                if climate != {} :

                    cli_long = climate['longitude']
                    cli_lat = climate['latitude']
            
                    # pygeohash format
                    cli_encode_info = pgh.encode(latitude=cli_lat, longitude=cli_long, precision=3)

                    
                    # now, need to think about the AQUA initial and TERRA initial
                    
                    for A_record in initial_AQUA:
                        AQUA_encode_info = pgh.encode(latitude = A_record['latitude'], longitude = A_record['longitude'], precision = 3 )
                        
                        if AQUA_encode_info == cli_encode_info:
                            A_record['sate'] = 'AQUA'
                            temp_hotspot.append(A_record)
                            
                    for T_record in initial_TERA:
                        TERA_encode_info = pgh.encode(latitude = T_record['latitude'], longitude = T_record['longitude'], precision = 3 )
                        
                        if TERA_encode_info == cli_encode_info:
                            T_record['sate'] = 'TERRA'
                            temp_hotspot.append(T_record)
                            
                    # Merge ‘surface temperature’ and ‘confidence’
                    
                    if len(temp_hotspot) > 1:
                        
                        # checking enter here
                        # print("alright, need to merge ~ ")
                        
                        merged_hotspot = list()
                        
                        merge_AQUA = list()
                        merge_TERA = list()
                        
                        for hotspot_info in temp_hotspot:
                            if hotspot_info['sate'] == 'AQUA':
                                merge_AQUA.append(hotspot_info)
                            else:
                                merge_TERA.append(hotspot_info)
                                
                        if len(merge_AQUA) > 0 and len(merge_TERA) > 0:
                            
                            for i in merge_AQUA:
                                compare5_AQUA_lat = i['latitude']
                                compare5_AQUA_long = i['longitude']
                                
                                for j in merge_TERA:
                                    encode5_AQUA = pgh.encode(latitude = compare5_AQUA_lat, longitude = compare5_AQUA_long, precision = 5)
                                    encode5_TERA = pgh.encode(latitude = j['latitude'], longitude = j['longitude'], precision = 5)
                                    
                                    # final check
                                    if encode5_AQUA == encode5_TERA:
                                        legit = dict()
                                        
                                        legit['avg_temperature'] = (i['surface_temperature_celcius'] + j['surface_temperature_celcius']) / 2
                                        legit['avg_confidence'] = (i['confidence'] + j['confidence']) / 2
                                        legit['latitude']  = compare5_AQUA_lat
                                        legit['longitude'] = compare5_AQUA_long
                                        
                                        merged_hotspot.append(legit)
                    

                    # checking is the event is natural or event
                    if len(temp_hotspot) > 0:
                        air_temp = float(climate['air_temperature_celcius'])
                        GHI = float(climate['GHI_w/m2'])
                        event = 'other'

                        if air_temp > 20 and GHI > 180:
                            event = 'natural'

                        for h in temp_hotspot:
                            h['event'] = event
                    
                    climate['hotspot'] = temp_hotspot
            
                    try:
                        db.hotspot.insert_one(climate)
                        
                    except pymongo.errors.DuplicateKeyError:
                        # This key has already in the database, so shouldn't use it.
                        pass
                    
                    except Exception as ex:
                        
                        print("An error occurred:", ex)


        
    except Exception as ex:
        print(ex)

# %%
db_writer = (
    stream
    .writeStream
    .foreachBatch(process_data)
    .outputMode('append')
    .trigger(processingTime='10 seconds')
    .start()
)

# %%
# home
# client = MongoClient('mongodb://192.168.1.101:27017/')

# library
client = MongoClient('mongodb://10.192.0.143:27017/')


# list of database before we delete
result = client.list_database_names()
#print(result)

# make database
db = client.fit3182_assignment1_db

# add new collection into new database
#db.hotspot.drop()

# %%
import threading

def stop_db_writer():
    print('Stopping query after timeout.')
    db_writer.stop()

try:
    # it will automatically stop with  stop_db_writer fuction, 5 min
    timer = threading.Timer(600, stop_db_writer)
    timer.start()
    
    # wait till it finish
    db_writer.awaitTermination()
    
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopping query.')
    db_writer.stop()
# Out:
# Stopping query after timeout.

# %% [markdown]
# There will be an error if the key (_id) has been collusion, therefore, i used try and except( Duplicate Key Error)

# %%
cursor = db.hotspot.find({})
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('6654124cc91afa9b100d87b5'), 'latitude': -38.038, 'longitude': 142.986, 'air_temperature_celcius': 15.0, 'relative_humidity': 50.7, 'windspeed_knots': 9.2, 'max_wind_speed': 13.0, 'precipitation ': ' 0.02G', 'GHI_w/m2': 128.0, 'created_time': '2024-03-09 00:00:00', 'producer': 'producer1', 'hotspot': [{'latitude':
 'max_wind_speed': 14.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 141.0, 'created_time': '2024-04-15 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('665413c8c91afa9b100d87db'), 'latitude': -37.603, 'longitude': 149.324, 'air_temperature_celcius': 16.0, 'relative_humidity': 53.6, 'windspeed_knots': 12.1, 'max_wind_speed': 16.9, 'precipitation ': ' 0.16G', 'GHI_w/m2': 133.0, 'created_time': '2024-04-16 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('665413d2c91afa9b100d87dc'), 'latitude': -37.333, 'longitude': 148.099, 'air_temperature_celcius': 10.0, 'relative_humidity': 35.6, 'windspeed_knots': 14.5, 'max_wind_speed': 20.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 96.0, 'created_time': '2024-04-17 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('665413dcc91afa9b100d87dd'), 'latitude': -38.038, 'longitude': 142.986, 'air_temperature_celcius': 15.0, 'relative_humidity': 50.7, 'windspeed_knots': 9.2, 'max_wind_speed': 13.0, 'precipitation ': ' 0.02G', 'GHI_w/m2': 128.0, 'created_time': '2024-04-18 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('665413e6c91afa9b100d87de'), 'latitude': -37.926, 'longitude': 144.0898, 'air_temperature_celcius': 15.0, 'relative_humidity': 51.0, 'windspeed_knots': 9.0, 'max_wind_speed': 13.0, 'precipitation ': ' 1.26G', 'GHI_w/m2': 128.0, 'created_time': '2024-04-19 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('665413f0c91afa9b100d87df'), 'latitude': -37.5268, 'longitude': 143.0551, 'air_temperature_celcius': 8.0, 'relative_humidity': 35.0, 'windspeed_knots': 14.4, 'max_wind_speed': 20.0, 'precipitation ': ' 0.00G', 'GHI_w/m2': 77.0, 'created_time': '2024-04-20 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('665413fac91afa9b100d87e0'), 'latitude': -37.45, 'longitude': 148.126, 'air_temperature_celcius': 11.0, 'relative_humidity': 40.5, 'windspeed_knots': 13.4, 'max_wind_speed': 26.0, 'precipitation ': ' 0.00G', 'GHI_w/m2': 102.0, 'created_time': '2024-04-21 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('66541404c91afa9b100d87e1'), 'latitude': -36.8741, 'longitude': 143.91, 'air_temperature_celcius': 9.0, 'relative_humidity': 41.9, 'windspeed_knots': 9.2, 'max_wind_speed': 14.0, 'precipitation ': ' 0.12G', 'GHI_w/m2': 82.0, 'created_time': '2024-04-22 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('6654140ec91afa9b100d87e2'), 'latitude': -37.623, 'longitude': 149.323, 'air_temperature_celcius': 19.0, 'relative_humidity': 56.8, 'windspeed_knots': 7.9, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'GHI_w/m2': 154.0, 'created_time': '2024-04-23 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('66541418c91afa9b100d87e3'), 'latitude': -37.389, 'longitude': 149.311, 'air_temperature_celcius': 18.0, 'relative_humidity': 53.0, 'windspeed_knots': 6.6, 'max_wind_speed': 14.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 150.0, 'created_time': '2024-04-24 00:00:00', 'producer': 'producer1', 'hotspot': [{'latitude': -37.62, 'longitude': 149.294, 'confidence': 87.0, 'surface_temperature_celcius': 63.0, 'created_time': '2024-01-01 17:50:37', 'producer': 'producer3', 'sate': 'TERRA', 'event': 'other'}]}
# {'_id': ObjectId('66541422c91afa9b100d87e4'), 'latitude': -37.598, 'longitude': 149.29, 'air_temperature_celcius': 18.0, 'relative_humidity': 53.5, 'windspeed_knots': 8.8, 'max_wind_speed': 13.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 150.0, 'created_time': '2024-04-25 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('6654142cc91afa9b100d87e5'), 'latitude': -37.446, 'longitude': 148.102, 'air_temperature_celcius': 10.0, 'relative_humidity': 39.4, 'windspeed_knots': 9.6, 'max_wind_speed': 14.0, 'precipitation ': ' 0.00G', 'GHI_w/m2': 93.0, 'created_time': '2024-04-26 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('66541436c91afa9b100d87e6'), 'latitude': -36.282, 'longitude': 146.157, 'air_temperature_celcius': 17.0, 'relative_humidity': 50.4, 'windspeed_knots': 11.9, 'max_wind_speed': 16.9, 'precipitation ': ' 0.00G', 'GHI_w/m2': 145.0, 'created_time': '2024-04-27 00:00:00', 'producer': 'producer1', 'hotspot': [{'latitude': -36.0816, 'longitude': 145.859, 'confidence': 100.0, 'surface_temperature_celcius': 98.0, 'created_time': '2024-01-01 16:29:36', 'producer': 'producer2', 'sate': 'AQUA', 'event': 'other'}]}
# {'_id': ObjectId('66541440c91afa9b100d87e7'), 'latitude': -38.226, 'longitude': 147.167, 'air_temperature_celcius': 10.0, 'relative_humidity': 43.7, 'windspeed_knots': 7.2, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'GHI_w/m2': 90.0, 'created_time': '2024-04-28 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('6654144ac91afa9b100d87e8'), 'latitude': -37.384, 'longitude': 149.336, 'air_temperature_celcius': 16.0, 'relative_humidity': 48.9, 'windspeed_knots': 5.4, 'max_wind_speed': 8.9, 'precipitation ': ' 0.00I', 'GHI_w/m2': 138.0, 'created_time': '2024-04-29 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('66541454c91afa9b100d87e9'), 'latitude': -37.295, 'longitude': 144.377, 'air_temperature_celcius': 16.0, 'relative_humidity': 54.8, 'windspeed_knots': 8.3, 'max_wind_speed': 9.9, 'precipitation ': ' 0.00G', 'GHI_w/m2': 132.0, 'created_time': '2024-04-30 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('6654145ec91afa9b100d87ea'), 'latitude': -37.609, 'longitude': 149.32, 'air_temperature_celcius': 16.0, 'relative_humidity': 48.3, 'windspeed_knots': 9.4, 'max_wind_speed': 14.0, 'precipitation ': ' 0.01G', 'GHI_w/m2': 139.0, 'created_time': '2024-05-01 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('66541468c91afa9b100d87eb'), 'latitude': -37.461, 'longitude': 148.103, 'air_temperature_celcius': 10.0, 'relative_humidity': 45.9, 'windspeed_knots': 3.2, 'max_wind_speed': 7.0, 'precipitation ': ' 0.00G', 'GHI_w/m2': 89.0, 'created_time': '2024-05-02 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('66541472c91afa9b100d87ec'), 'latitude': -37.365, 'longitude': 148.052, 'air_temperature_celcius': 11.0, 'relative_humidity': 43.8, 'windspeed_knots': 6.5, 'max_wind_speed': 12.0, 'precipitation ': ' 0.02G', 'GHI_w/m2': 99.0, 'created_time': '2024-05-03 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('6654147cc91afa9b100d87ed'), 'latitude': -36.94, 'longitude': 143.281, 'air_temperature_celcius': 21.0, 'relative_humidity': 52.8, 'windspeed_knots': 4.1, 'max_wind_speed': 11.1, 'precipitation ': ' 0.00I', 'GHI_w/m2': 176.0, 'created_time': '2024-05-04 00:00:00', 'producer': 'producer1', 'hotspot': [{'latitude': -36.5642, 'longitude': 142.5943, 'confidence': 51.0, 'surface_temperature_celcius': 38.0, 'created_time': '2024-01-01 05:20:45', 'producer': 'producer2', 'sate': 'AQUA', 'event': 'other'}]}
# {'_id': ObjectId('66541486c91afa9b100d87ee'), 'latitude': -37.623, 'longitude': 149.284, 'air_temperature_celcius': 21.0, 'relative_humidity': 64.5, 'windspeed_knots': 10.6, 'max_wind_speed': 15.9, 'precipitation ': ' 1.26G', 'GHI_w/m2': 158.0, 'created_time': '2024-05-05 00:00:00', 'producer': 'producer1', 'hotspot': []}
# {'_id': ObjectId('66541490c91afa9b100d87ef'), 'latitude': -37.467, 'longitude': 143.351, 'air_temperature_celcius': 17.0, 'relative_humidity': 53.4, 'windspeed_knots': 9.4, 'max_wind_speed': 25.1, 'precipitation ': ' 0.16G', 'GHI_w/m2': 142.0, 'created_time': '2024-05-06 00:00:00', 'producer': 'producer1', 'hotspot': []}

# %% [markdown]
# The below function which is "process_data2" is the fucntion for in case if merging is not working.
