# %% [markdown]
# # Task 2-1 Streaming data visualisation
#
# ## 2-1-a

# %%
# import statements
from time import sleep
from kafka3 import KafkaConsumer
import datetime as dt
import matplotlib.pyplot as plt
import json

# %%
# home
# hostip = "192.168.1.101"

# library
hostip = "10.192.0.143"

# %%
# display of graphs in Jupyter Notebook
# %matplotlib notebook

topic = 'PartB1'

def annotate_max(x, y, ax=None):
    if ax is None:
        ax = plt.gca()
        
    ymax = max(y)
    xpos = y.index(ymax)
    xmax = x[xpos]
    text = 'Max: Time={}, Value={}'.format(xmax, ymax)
    
    ax.annotate(text, xy=(xmax, ymax), xytext=(xmax, ymax+5), arrowprops=dict(facecolor='red', shrink=0.05))

def annotate_min(x, y, ax=None):
    if ax is None:
        ax = plt.gca()
        
    ymin = min(y)
    xpos = y.index(ymin)
    xmin = x[xpos]
    text = 'Min: Time={}, Value={}'.format(xmin, ymin)
    
    ax.annotate(text, xy=(xmin, ymin), xytext=(xmin, ymin+5), arrowprops=dict(facecolor='orange', shrink=0.05))

def connect_kafka_consumer():
    _consumer = None
    try:
         _consumer = KafkaConsumer(topic,
                                   consumer_timeout_ms=15000, # stop iteration if no message after 15 sec
                                   bootstrap_servers=[f'{hostip}:9092'],
                                   api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _consumer

def init_plots():
    try:
        width = 9.5
        height = 6
        fig = plt.figure(figsize=(width,height)) # create new figure
        ax = fig.add_subplot(111) # adding the subplot axes to the given grid position
        fig.suptitle('Real-time uniform stream data visualization with temperature') # giving figure a title
        ax.set_xlabel('Air temperature')
        ax.set_ylabel('Arrival time')
        ax.set_ylim(0,110) 
        ax.set_yticks([0,20,40,60,80,100])
        
        ax.tick_params(axis='x', rotation=30)  # Adjust the rotation angle as needed

        fig.show() # displaying the figure
        fig.canvas.draw() # drawing on the canvas
        return fig, ax
    except Exception as ex:
        print(str(ex))
    
def consume_messages(consumer, fig, ax):
    try:
        # container for x and y values
        x, y = [], []
        print('Waiting for messages')
        for message in consumer:
            data = str(message.value.decode('utf-8')).split(', ')

            key = message.key.decode("utf-8")
            
            if key == 'producer1':

                decode = str(message.value.decode('utf-8'))
                data = json.loads(decode)
                # print(data)
                x.append(data['created_time'][:10])

                y.append(float(data['air_temperature_celcius']))
                
#                 print(data['air_temperature_celcius'])

                # we start plotting only when we have 10 data points
                
                if len(y) > 9:
                    
                    ax.clear()
                    ax.plot(x, y)
                    ax.set_xlabel('Arrival Time')
                    ax.set_ylabel('Air Temperature')
                    ax.set_ylim(0,50) 
                    ax.set_yticks([0,20,40])
                    annotate_max(x,y)
                    annotate_min(x,y)
                    fig.canvas.draw()
                    
                    x.pop(0) # removing the item in the first position
                    y.pop(0)
                    
                 
                    
#         plt.close('all')
    except Exception as ex:
        print(str(ex))
    
if __name__ == '__main__':
    
    consumer = connect_kafka_consumer()
    fig, ax = init_plots()
    consume_messages(consumer, fig, ax)
# Out:
# <img src="data:image/png;base64,..." width="950">
# Waiting for messages
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 109
#     107 consumer = connect_kafka_consumer()
#     108 fig, ax = init_plots()
# --> 109 consume_messages(consumer, fig, ax)
#
# Cell In[3], line 66, in consume_messages(consumer, fig, ax)
#      64 x, y = [], []
#      65 print('Waiting for messages')
# ---> 66 for message in consumer:
#      67     data = str(message.value.decode('utf-8')).split(', ')
#      69     key = message.key.decode("utf-8")
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:1197, in KafkaConsumer.__next__(self)
#    1195     return self.next_v1()
#    1196 else:
# -> 1197     return self.next_v2()
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:1205, in KafkaConsumer.next_v2(self)
#    1203     self._iterator = self._message_generator_v2()
#    1204 try:
# -> 1205     return next(self._iterator)
#    1206 except StopIteration:
#    1207     self._iterator = None
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:1120, in KafkaConsumer._message_generator_v2(self)
#    1118 def _message_generator_v2(self):
#    1119     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1120     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1121     for tp, records in six.iteritems(record_map):
#    1122         # Generators are stateful, and it is possible that the tp / records
#    1123         # here may become stale during iteration -- i.e., we seek to a
#    1124         # different offset, pause consumption, or lose assignment.
#    1125         for record in records:
#    1126             # is_fetchable(tp) should handle assignment changes and offset
#    1127             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1128             # outer function destroying the existing iterator/generator
#    1129             # via self._iterator = None
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:657, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     655 remaining = timeout_ms
#     656 while not self._closed:
# --> 657     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     658     if records:
#     659         return records
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:706, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     703     self._client.poll(timeout_ms=0)
#     705 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 706 self._client.poll(timeout_ms=timeout_ms)
#     707 # after the long poll, we should check whether the group needs to rebalance
#     708 # prior to returning data so that the group can stabilize faster
#     709 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /opt/conda/lib/python3.8/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# during 2024-01-27 ~ 2024-02-05, the lowest air temperature is 8'C, on 2024-01-30. the highest air temperature is 28'C on 2024-02-04

# %% [markdown]
# # Task 2-2 Static data visualisation
#
# ## 2-2-a

# %%
import sys, getopt, pprint
from pymongo import MongoClient
from pprint import pprint
from datetime import datetime as datetime

# home
# client = MongoClient('mongodb://192.168.1.101:27017/')

# library
client = MongoClient('mongodb://10.192.0.143:27017/')

# make database
db = client.fit3182_assignment1_db

# add new collection into new database
collection = db.hotspot

# %%
from pymongo import MongoClient
from collections import defaultdict

# set the dictionary, it will be based on the time 0 ~ 23
Daytohour = defaultdict(int)



# collect all the data
for document in collection.find():
    
    # get hotspot information
    hotspot_data = document.get('hotspot', [])
    
    # find the hour
    for hotspot in hotspot_data:
        datetime_obj = hotspot.get('created_time')
        datetime_obj = datetime.strptime(datetime_obj, "%Y-%m-%d %H:%M:%S")
    
        if datetime_obj:
            hour = datetime_obj.hour

            Daytohour[hour] += 1

# result for the number of "hour"
for hour in range(24):
    count = Daytohour[hour]
    print(f"Hour: {hour}, Count: {count}")
# Out:
# Hour: 0, Count: 0
# Hour: 1, Count: 0
# Hour: 2, Count: 0
# Hour: 3, Count: 1
# Hour: 4, Count: 1
# Hour: 5, Count: 1
# Hour: 6, Count: 0
# Hour: 7, Count: 0
# Hour: 8, Count: 0
# Hour: 9, Count: 0
# Hour: 10, Count: 0
# Hour: 11, Count: 0
# Hour: 12, Count: 0
# Hour: 13, Count: 0
# Hour: 14, Count: 0
# Hour: 15, Count: 0
# Hour: 16, Count: 1
# Hour: 17, Count: 2
# Hour: 18, Count: 0
# Hour: 19, Count: 0
# Hour: 20, Count: 0
# Hour: 21, Count: 0
# Hour: 22, Count: 1
# Hour: 23, Count: 1

# %%
# prepare for making barplot from our dict dataset

hours = list(Daytohour.keys())
counts = list(Daytohour.values())

# barplot
plt.figure(figsize=(10, 5))
plt.bar(hours, counts, color='skyblue')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Hotspots')
plt.title('Number of Hotspots by Hour of Day')
plt.xticks(range(24))  # 24 hour format time.
plt.grid(axis='y')

# show
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## 2-2-b

# %%
import folium
from pprint import pprint

#Melbourne city
m = folium.Map(location = [-37.8136, 144.9631], zoom_start=6)

# %%
fire_lst = []

for document in collection.find():
    
    if len(document['hotspot']) != 0:

        h_air_temp = document['air_temperature_celcius']
        h_humidity = document['relative_humidity']
        info = document['hotspot']

        for i in info:
            h_latitude = i['latitude']
            h_longitude = i['longitude']
            h_surface_temp = i['surface_temperature_celcius']
            h_confidence = i['confidence']
            h_event = i['event']

            fire_lst.append([h_latitude, h_longitude, h_air_temp, h_surface_temp, h_humidity, h_confidence, h_event])
# pprint(fire_lst)

# %%
import pandas as pd

final_data = []

# add the attribute into the data frame
for record in fire_lst:
    final_data.append({
        'h_latitude': record[0],
        'h_longitude': record[1],
        'h_air_temp': record[2],
        'h_surface_temp': record[3],
        'h_humidity': record[4],
        'h_confidence': record[5],
        'h_event': record[6]
    })
    
# make dataframe
final_DataFrame = pd.DataFrame(final_data)

# print dataframe
final_DataFrame
# Out:
#    h_latitude  h_longitude  h_air_temp  h_surface_temp  h_humidity  \
# 0    -38.0795     143.2449        15.0            91.0        50.7
# 1    -36.8763     142.7266        19.0            44.0        58.7
# 2    -36.1598     141.8841        10.0            64.0        42.1
# 3    -37.5025     142.9011        17.0            47.0        49.9
# 4    -37.7795     148.4084         9.0            53.0        45.3
# 5    -37.6200     149.2940        18.0            63.0        53.0
# 6    -36.0816     145.8590        17.0            98.0        50.4
# 7    -36.5642     142.5943        21.0            38.0        52.8
#
#    h_confidence h_event
# 0         100.0   other
# 1          68.0   other
# 2          88.0   other
# 3          73.0   other
# 4          79.0   other
# 5          87.0   other
# 6         100.0   other
# 7          51.0   other

# %%
for i in range(0, len(final_DataFrame)):
    folium.Marker(
        location=[final_DataFrame.iloc[i]['h_latitude'], final_DataFrame.iloc[i]['h_longitude']],
        popup=folium.Popup(
            "Air temperature: {}°C\n".format(final_DataFrame.iloc[i]['h_air_temp']) +
            "Surface Temperature: {}°C\n".format(final_DataFrame.iloc[i]['h_surface_temp']) +
            "Relative Humidity: {}%\n".format(final_DataFrame.iloc[i]['h_humidity']) +
            "Confidence: {}%\n".format(final_DataFrame.iloc[i]['h_confidence'])
        ), 
        icon=folium.Icon(color='red') if final_DataFrame.iloc[i]['h_event'] == 'other' else folium.Icon(color='blue')
    ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d280e30ce16d48516f2cb44db862b6b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d280e30ce16d48516f2cb44db862b6b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d280e30ce16d48516f2cb44db862b6b2 = L.map(
#                 &quot;map_d280e30ce16d48516f2cb44db862b6b2&quot;,
#                 {
#                     center: [-37.8136, 144.9631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbaee332dab20e1efbf65515f3c6fed8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cbaee332dab20e1efbf65515f3c6fed8.addTo(map_d280e30ce16d48516f2cb44db862b6b2);
#
#
#             var marker_9854c5378cdb631dbb0bba863e2f3d4f = L.marker(
#                 [-38.0795, 143.2449],
#                 {}
#             ).addTo(map_d280e30ce16d48516f2cb44db862b6b2);
#
#
#             var icon_05e18abf357c59083adf6a8da3592e19 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9854c5378cdb631dbb0bba863e2f3d4f.setIcon(icon_05e18abf357c59083adf6a8da3592e19);
#
#
#         var popup_031e8c37496a00c8f023b47dbde13f62 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0352d30de09e6a0b77ac836fdcf6b22 = $(`&lt;div id=&quot;html_a0352d30de09e6a0b77ac836fdcf6b22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Air temperature: 15.0°C Surface Temperature: 91.0°C Relative Humidity: 50.7% Confidence: 100.0% &lt;/div&gt;`)[0];
#                 popup_031e8c37496a00c8f023b47dbde13f62.setContent(html_a0352d30de09e6a0b77ac836fdcf6b22);
#
#
#
#         marker_9854c5378cdb631dbb0bba863e2f3d4f.bindPopup(popup_031e8c37496a00c8f023b47dbde13f62)
#         ;
#
#
#
#
#             var marker_f7f8255d036c329bc5d347c634700a52 = L.marker(
#                 [-36.8763, 142.7266],
#                 {}
#             ).addTo(map_d280e30ce16d48516f2cb44db862b6b2);
#
#
#             var icon_7df965b4f30d3fbd9522cd015beb538e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f7f8255d036c329bc5d347c634700a52.setIcon(icon_7df965b4f30d3fbd9522cd015beb538e);
#
#
#         var popup_1d7ca60ff55db4eb890d356bd122d762 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e833938dfb453a7cafd8b3497f51ef1 = $(`&lt;div id=&quot;html_6e833938dfb453a7cafd8b3497f51ef1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Air temperature: 19.0°C Surface Temperature: 44.0°C Relative Humidity: 58.7% Confidence: 68.0% &lt;/div&gt;`)[0];
#                 popup_1d7ca60ff55db4eb890d356bd122d762.setContent(html_6e833938dfb453a7cafd8b3497f51ef1);
#
#
#
#         marker_f7f8255d036c329bc5d347c634700a52.bindPopup(popup_1d7ca60ff55db4eb890d356bd122d762)
#         ;
#
#
#
#
#             var marker_b86fc7e7eb57f66fe3170c25b9152a33 = L.marker(
#                 [-36.1598, 141.8841],
#                 {}
#             ).addTo(map_d280e30ce16d48516f2cb44db862b6b2);
#
#
#             var icon_b85a48c8b85ad58bbc0ab21f15e4d105 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b86fc7e7eb57f66fe3170c25b9152a33.setIcon(icon_b85a48c8b85ad58bbc0ab21f15e4d105);
#
#
#         var popup_fcd906952be942ba7786a587f4262c56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5229b95244d5af02b080b1adb9b164e9 = $(`&lt;div id=&quot;html_5229b95244d5af02b080b1adb9b164e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Air temperature: 10.0°C Surface Temperature: 64.0°C Relative Humidity: 42.1% Confidence: 88.0% &lt;/div&gt;`)[0];
#                 popup_fcd906952be942ba7786a587f4262c56.setContent(html_5229b95244d5af02b080b1adb9b164e9);
#
#
#
#         marker_b86fc7e7eb57f66fe3170c25b9152a33.bindPopup(popup_fcd906952be942ba7786a587f4262c56)
#         ;
#
#
#
#
#             var marker_a4862e7387b488decebdd1704db50819 = L.marker(
#                 [-37.5025, 142.9011],
#                 {}
#             ).addTo(map_d280e30ce16d48516f2cb44db862b6b2);

# %% [markdown]
# I could see that there is 1 natural, and 3 others data.
