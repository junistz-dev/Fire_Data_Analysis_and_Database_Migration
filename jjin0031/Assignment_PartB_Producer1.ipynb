# %%
# import statements
from pymongo import MongoClient

import csv
from time import sleep
from json import dumps
from kafka3 import KafkaProducer
import random
import pandas as pd
import datetime as dt
import json
import pymongo

#hostip = '192.168.1.101'

# home
# client = MongoClient('mongodb://192.168.1.101:27017/')

# library
hostip = '10.192.1.37'
client = MongoClient('mongodb://10.192.1.37:27017/')


db = client.fit3182_assignment1_db

collection = db.merged_history

def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        
        producer_instance.send(topic_name, key = key_bytes, value=value_bytes)
        
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(value))
        
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[f'{hostip}:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer

if __name__ == '__main__':

    topic = 'PartB1'
    array = []
    
    # for finding the latest date.
    with open('climate_streaming.csv', 'r') as file:
        reader = csv.DictReader(file)

        for row in reader:  
            array.append(row)
            
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    # finding the latest date in the climate data with sort - descending
    latest_record = collection.find().sort([('date', pymongo.DESCENDING)]).limit(1)
    latest_date = latest_record[0]['date']
    
    
    # pick data with random.randrange
    for _ in range(len(array)):
        random_number = random.randrange(0, len(array))
        random_data = array[random_number]
        #print(random_data)
        latest_date += dt.timedelta(days=1)    
        
        # set date to string 
        random_data['created_time'] = latest_date.isoformat()
        random_data['producer'] = 'producer1'

        #key = producer1
        publish_message(producer, topic, "producer1", json.dumps(random_data))
        sleep(10)
# Out:
# Publishing records..
# Message published successfully. Data: {"latitude": "-37.603", "longitude": "149.324", "air_temperature_celcius": "16", "relative_humidity": "53.6", "windspeed_knots": "12.1", "max_wind_speed": "16.9", "precipitation ": " 0.16G", "GHI_w/m2": "133", "created_time": "2024-01-02T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.602", "longitude": "149.295", "air_temperature_celcius": "17", "relative_humidity": "50.8", "windspeed_knots": "9", "max_wind_speed": "15.9", "precipitation ": " 0.00G", "GHI_w/m2": "145", "created_time": "2024-01-03T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.156", "longitude": "143.568", "air_temperature_celcius": "13", "relative_humidity": "51.4", "windspeed_knots": "4.6", "max_wind_speed": "8.9", "precipitation ": " 0.00I", "GHI_w/m2": "110", "created_time": "2024-01-04T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.591", "longitude": "149.33", "air_temperature_celcius": "16", "relative_humidity": "46.7", "windspeed_knots": "10", "max_wind_speed": "16.9", "precipitation ": " 0.00I", "GHI_w/m2": "141", "created_time": "2024-01-05T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.247", "longitude": "141.278", "air_temperature_celcius": "14", "relative_humidity": "47.4", "windspeed_knots": "7.1", "max_wind_speed": "14", "precipitation ": " 0.00I", "GHI_w/m2": "123", "created_time": "2024-01-06T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.562", "longitude": "148.05", "air_temperature_celcius": "7", "relative_humidity": "40.5", "windspeed_knots": "3.1", "max_wind_speed": "8", "precipitation ": " 0.00I", "GHI_w/m2": "65", "created_time": "2024-01-07T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-35.957", "longitude": "141.088", "air_temperature_celcius": "9", "relative_humidity": "42.4", "windspeed_knots": "7.2", "max_wind_speed": "9.9", "precipitation ": " 0.00I", "GHI_w/m2": "82", "created_time": "2024-01-08T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-34.5374", "longitude": "141.7141", "air_temperature_celcius": "8", "relative_humidity": "40.8", "windspeed_knots": "5.5", "max_wind_speed": "9.9", "precipitation ": " 0.01G", "GHI_w/m2": "74", "created_time": "2024-01-09T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.851", "longitude": "148.117", "air_temperature_celcius": "9", "relative_humidity": "45.3", "windspeed_knots": "2.5", "max_wind_speed": "6", "precipitation ": " 0.00G", "GHI_w/m2": "80", "created_time": "2024-01-10T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.5775", "longitude": "142.6076", "air_temperature_celcius": "19", "relative_humidity": "58.7", "windspeed_knots": "5.5", "max_wind_speed": "12", "precipitation ": " 0.28G", "GHI_w/m2": "151", "created_time": "2024-01-11T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.448", "longitude": "148.114", "air_temperature_celcius": "10", "relative_humidity": "44.4", "windspeed_knots": "5.6", "max_wind_speed": "11.1", "precipitation ": " 0.12G", "GHI_w/m2": "90", "created_time": "2024-01-12T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.778", "longitude": "145.1635", "air_temperature_celcius": "17", "relative_humidity": "46.3", "windspeed_knots": "11.7", "max_wind_speed": "20", "precipitation ": " 0.02G", "GHI_w/m2": "150", "created_time": "2024-01-13T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.461", "longitude": "148.103", "air_temperature_celcius": "10", "relative_humidity": "45.9", "windspeed_knots": "3.2", "max_wind_speed": "7", "precipitation ": " 0.00G", "GHI_w/m2": "89", "created_time": "2024-01-14T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.3847", "longitude": "142.8935", "air_temperature_celcius": "20", "relative_humidity": "43.6", "windspeed_knots": "10.3", "max_wind_speed": "15", "precipitation ": " 0.00I", "GHI_w/m2": "181", "created_time": "2024-01-15T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.461", "longitude": "148.105", "air_temperature_celcius": "10", "relative_humidity": "45.6", "windspeed_knots": "4.5", "max_wind_speed": "7", "precipitation ": " 0.00I", "GHI_w/m2": "89", "created_time": "2024-01-16T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.0714", "longitude": "145.7665", "air_temperature_celcius": "18", "relative_humidity": "54.6", "windspeed_knots": "12", "max_wind_speed": "25.1", "precipitation ": " 0.12G", "GHI_w/m2": "148", "created_time": "2024-01-17T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.749", "longitude": "148.297", "air_temperature_celcius": "17", "relative_humidity": "52.6", "windspeed_knots": "10.3", "max_wind_speed": "15.9", "precipitation ": " 0.00G", "GHI_w/m2": "143", "created_time": "2024-01-18T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.6732", "longitude": "142.5162", "air_temperature_celcius": "19", "relative_humidity": "53.9", "windspeed_knots": "8.3", "max_wind_speed": "14", "precipitation ": " 0.00I", "GHI_w/m2": "158", "created_time": "2024-01-19T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.295", "longitude": "144.377", "air_temperature_celcius": "16", "relative_humidity": "54.8", "windspeed_knots": "8.3", "max_wind_speed": "9.9", "precipitation ": " 0.00G", "GHI_w/m2": "132", "created_time": "2024-01-20T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.4551", "longitude": "143.7902", "air_temperature_celcius": "9", "relative_humidity": "37.9", "windspeed_knots": "9.1", "max_wind_speed": "15.9", "precipitation ": " 0.00G", "GHI_w/m2": "85", "created_time": "2024-01-21T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.365", "longitude": "148.052", "air_temperature_celcius": "11", "relative_humidity": "43.8", "windspeed_knots": "6.5", "max_wind_speed": "12", "precipitation ": " 0.02G", "GHI_w/m2": "99", "created_time": "2024-01-22T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.293", "longitude": "146.148", "air_temperature_celcius": "16", "relative_humidity": "50.8", "windspeed_knots": "5.8", "max_wind_speed": "12", "precipitation ": " 0.00I", "GHI_w/m2": "136", "created_time": "2024-01-23T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.229", "longitude": "141.182", "air_temperature_celcius": "8", "relative_humidity": "44.5", "windspeed_knots": "4.7", "max_wind_speed": "7", "precipitation ": " 0.01G", "GHI_w/m2": "72", "created_time": "2024-01-24T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.463", "longitude": "148.109", "air_temperature_celcius": "11", "relative_humidity": "45.1", "windspeed_knots": "5.6", "max_wind_speed": "9.9", "precipitation ": " 0.00I", "GHI_w/m2": "98", "created_time": "2024-01-25T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-38.912", "longitude": "146.272", "air_temperature_celcius": "18", "relative_humidity": "53.3", "windspeed_knots": "10.8", "max_wind_speed": "15", "precipitation ": " 0.00G", "GHI_w/m2": "150", "created_time": "2024-01-26T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.538", "longitude": "141.129", "air_temperature_celcius": "12", "relative_humidity": "43.4", "windspeed_knots": "9.3", "max_wind_speed": "15", "precipitation ": " 0.00I", "GHI_w/m2": "109", "created_time": "2024-01-27T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.275", "longitude": "146.154", "air_temperature_celcius": "18", "relative_humidity": "53.3", "windspeed_knots": "7.9", "max_wind_speed": "14", "precipitation ": " 0.00I", "GHI_w/m2": "150", "created_time": "2024-01-28T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-38.141", "longitude": "143.183", "air_temperature_celcius": "23", "relative_humidity": "54.1", "windspeed_knots": "5.7", "max_wind_speed": "14", "precipitation ": " 0.00I", "GHI_w/m2": "190", "created_time": "2024-01-29T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.4661", "longitude": "143.2419", "air_temperature_celcius": "14", "relative_humidity": "48.2", "windspeed_knots": "9.1", "max_wind_speed": "15", "precipitation ": " 0.00G", "GHI_w/m2": "122", "created_time": "2024-01-30T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.602", "longitude": "149.295", "air_temperature_celcius": "17", "relative_humidity": "50.8", "windspeed_knots": "9", "max_wind_speed": "15.9", "precipitation ": " 0.00G", "GHI_w/m2": "145", "created_time": "2024-01-31T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.538", "longitude": "141.129", "air_temperature_celcius": "12", "relative_humidity": "43.4", "windspeed_knots": "9.3", "max_wind_speed": "15", "precipitation ": " 0.00I", "GHI_w/m2": "109", "created_time": "2024-02-01T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.382", "longitude": "149.341", "air_temperature_celcius": "18", "relative_humidity": "53.6", "windspeed_knots": "7.2", "max_wind_speed": "15", "precipitation ": " 0.00I", "GHI_w/m2": "150", "created_time": "2024-02-02T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.0005", "longitude": "143.1847", "air_temperature_celcius": "17", "relative_humidity": "52.5", "windspeed_knots": "7.7", "max_wind_speed": "16.9", "precipitation ": " 0.00I", "GHI_w/m2": "143", "created_time": "2024-02-03T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-35.89", "longitude": "145.606", "air_temperature_celcius": "15", "relative_humidity": "45.6", "windspeed_knots": "10.2", "max_wind_speed": "15", "precipitation ": " 0.00G", "GHI_w/m2": "133", "created_time": "2024-02-04T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.864", "longitude": "144.174", "air_temperature_celcius": "28", "relative_humidity": "58.4", "windspeed_knots": "11.9", "max_wind_speed": "18.1", "precipitation ": " 0.04G", "GHI_w/m2": "223", "created_time": "2024-02-05T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.467", "longitude": "143.351", "air_temperature_celcius": "17", "relative_humidity": "53.4", "windspeed_knots": "9.4", "max_wind_speed": "25.1", "precipitation ": " 0.16G", "GHI_w/m2": "142", "created_time": "2024-02-06T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.863", "longitude": "144.17", "air_temperature_celcius": "18", "relative_humidity": "57.5", "windspeed_knots": "16.1", "max_wind_speed": "21", "precipitation ": " 0.00G", "GHI_w/m2": "145", "created_time": "2024-02-07T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.608", "longitude": "149.282", "air_temperature_celcius": "22", "relative_humidity": "62.7", "windspeed_knots": "7.6", "max_wind_speed": "18.1", "precipitation ": " 0.00I", "GHI_w/m2": "169", "created_time": "2024-02-08T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-38.127", "longitude": "143.82", "air_temperature_celcius": "9", "relative_humidity": "44", "windspeed_knots": "2.8", "max_wind_speed": "8", "precipitation ": " 0.00I", "GHI_w/m2": "81", "created_time": "2024-02-09T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.3328", "longitude": "146.0355", "air_temperature_celcius": "7", "relative_humidity": "37.2", "windspeed_knots": "6.2", "max_wind_speed": "16.9", "precipitation ": " 0.08G", "GHI_w/m2": "66", "created_time": "2024-02-10T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.6", "longitude": "149.325", "air_temperature_celcius": "16", "relative_humidity": "48.1", "windspeed_knots": "9.3", "max_wind_speed": "12", "precipitation ": " 0.00G", "GHI_w/m2": "139", "created_time": "2024-02-11T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-35.953", "longitude": "141.078", "air_temperature_celcius": "12", "relative_humidity": "47.2", "windspeed_knots": "8.8", "max_wind_speed": "15", "precipitation ": " 0.00G", "GHI_w/m2": "105", "created_time": "2024-02-12T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.834", "longitude": "142.524", "air_temperature_celcius": "12", "relative_humidity": "47.3", "windspeed_knots": "9.7", "max_wind_speed": "14", "precipitation ": " 0.02G", "GHI_w/m2": "105", "created_time": "2024-02-13T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.886", "longitude": "147.207", "air_temperature_celcius": "19", "relative_humidity": "54.3", "windspeed_knots": "5.9", "max_wind_speed": "12", "precipitation ": " 0.00I", "GHI_w/m2": "157", "created_time": "2024-02-14T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.952", "longitude": "144.972", "air_temperature_celcius": "21", "relative_humidity": "57.3", "windspeed_knots": "5.4", "max_wind_speed": "9.9", "precipitation ": " 0.00I", "GHI_w/m2": "169", "created_time": "2024-02-15T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.485", "longitude": "148.095", "air_temperature_celcius": "11", "relative_humidity": "45.4", "windspeed_knots": "5.2", "max_wind_speed": "8.9", "precipitation ": " 0.00A", "GHI_w/m2": "98", "created_time": "2024-02-16T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.3756", "longitude": "143.7243", "air_temperature_celcius": "13", "relative_humidity": "47.1", "windspeed_knots": "8.1", "max_wind_speed": "12", "precipitation ": " 0.01G", "GHI_w/m2": "114", "created_time": "2024-02-17T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.238", "longitude": "141.145", "air_temperature_celcius": "8", "relative_humidity": "41.6", "windspeed_knots": "8.3", "max_wind_speed": "15.9", "precipitation ": " 0.24G", "GHI_w/m2": "73", "created_time": "2024-02-18T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.7685", "longitude": "142.7134", "air_temperature_celcius": "14", "relative_humidity": "48.2", "windspeed_knots": "12.5", "max_wind_speed": "19", "precipitation ": " 0.03G", "GHI_w/m2": "122", "created_time": "2024-02-19T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.4274", "longitude": "142.1944", "air_temperature_celcius": "22", "relative_humidity": "46.9", "windspeed_knots": "12.9", "max_wind_speed": "19", "precipitation ": " 0.00I", "GHI_w/m2": "193", "created_time": "2024-02-20T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.642", "longitude": "149.263", "air_temperature_celcius": "20", "relative_humidity": "55.8", "windspeed_knots": "10.5", "max_wind_speed": "15.9", "precipitation ": " 0.01G", "GHI_w/m2": "163", "created_time": "2024-02-21T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.583", "longitude": "149.316", "air_temperature_celcius": "25", "relative_humidity": "58.3", "windspeed_knots": "12.2", "max_wind_speed": "22", "precipitation ": " 0.04G", "GHI_w/m2": "199", "created_time": "2024-02-22T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-35.957", "longitude": "141.088", "air_temperature_celcius": "9", "relative_humidity": "42.4", "windspeed_knots": "7.2", "max_wind_speed": "9.9", "precipitation ": " 0.00I", "GHI_w/m2": "82", "created_time": "2024-02-23T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-38.167", "longitude": "143.841", "air_temperature_celcius": "21", "relative_humidity": "58.1", "windspeed_knots": "5.3", "max_wind_speed": "11.1", "precipitation ": " 0.00G", "GHI_w/m2": "168", "created_time": "2024-02-24T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.759", "longitude": "144.158", "air_temperature_celcius": "14", "relative_humidity": "52.5", "windspeed_knots": "7", "max_wind_speed": "13", "precipitation ": " 0.00G", "GHI_w/m2": "118", "created_time": "2024-02-25T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.0201", "longitude": "143.7775", "air_temperature_celcius": "18", "relative_humidity": "55.6", "windspeed_knots": "8.2", "max_wind_speed": "12", "precipitation ": " 0.00I", "GHI_w/m2": "147", "created_time": "2024-02-26T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-35.953", "longitude": "141.078", "air_temperature_celcius": "12", "relative_humidity": "47.2", "windspeed_knots": "8.8", "max_wind_speed": "15", "precipitation ": " 0.00G", "GHI_w/m2": "105", "created_time": "2024-02-27T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.6", "longitude": "149.325", "air_temperature_celcius": "16", "relative_humidity": "48.1", "windspeed_knots": "9.3", "max_wind_speed": "12", "precipitation ": " 0.00G", "GHI_w/m2": "139", "created_time": "2024-02-28T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.6686", "longitude": "142.5195", "air_temperature_celcius": "16", "relative_humidity": "47", "windspeed_knots": "12", "max_wind_speed": "16.9", "precipitation ": " 0.00I", "GHI_w/m2": "141", "created_time": "2024-02-29T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.779", "longitude": "146.108", "air_temperature_celcius": "13", "relative_humidity": "42", "windspeed_knots": "11.4", "max_wind_speed": "16.9", "precipitation ": " 0.00G", "GHI_w/m2": "119", "created_time": "2024-03-01T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.8147", "longitude": "143.1062", "air_temperature_celcius": "17", "relative_humidity": "46.4", "windspeed_knots": "9.5", "max_wind_speed": "20", "precipitation ": " 0.00I", "GHI_w/m2": "150", "created_time": "2024-03-02T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.477", "longitude": "148.097", "air_temperature_celcius": "8", "relative_humidity": "42.6", "windspeed_knots": "2", "max_wind_speed": "6", "precipitation ": " 0.00I", "GHI_w/m2": "73", "created_time": "2024-03-03T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.6312", "longitude": "142.5058", "air_temperature_celcius": "17", "relative_humidity": "52.5", "windspeed_knots": "5.7", "max_wind_speed": "11.1", "precipitation ": " 0.00I", "GHI_w/m2": "143", "created_time": "2024-03-04T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.692", "longitude": "143.593", "air_temperature_celcius": "14", "relative_humidity": "45.8", "windspeed_knots": "6.5", "max_wind_speed": "9.9", "precipitation ": " 0.00G", "GHI_w/m2": "124", "created_time": "2024-03-05T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.453", "longitude": "148.111", "air_temperature_celcius": "11", "relative_humidity": "45.3", "windspeed_knots": "10.6", "max_wind_speed": "16.9", "precipitation ": " 0.08G", "GHI_w/m2": "98", "created_time": "2024-03-06T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-35.892", "longitude": "145.62", "air_temperature_celcius": "10", "relative_humidity": "42.6", "windspeed_knots": "8.9", "max_wind_speed": "15", "precipitation ": " 0.04G", "GHI_w/m2": "91", "created_time": "2024-03-07T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.0669", "longitude": "141.0556", "air_temperature_celcius": "12", "relative_humidity": "47.5", "windspeed_knots": "15", "max_wind_speed": "18.1", "precipitation ": " 0.20G", "GHI_w/m2": "105", "created_time": "2024-03-08T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-36.942", "longitude": "143.282", "air_temperature_celcius": "25", "relative_humidity": "58.3", "windspeed_knots": "7.1", "max_wind_speed": "13", "precipitation ": " 0.00I", "GHI_w/m2": "199", "created_time": "2024-03-09T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.477", "longitude": "148.097", "air_temperature_celcius": "8", "relative_humidity": "42.6", "windspeed_knots": "2", "max_wind_speed": "6", "precipitation ": " 0.00I", "GHI_w/m2": "73", "created_time": "2024-03-10T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.864", "longitude": "144.174", "air_temperature_celcius": "28", "relative_humidity": "58.4", "windspeed_knots": "11.9", "max_wind_speed": "18.1", "precipitation ": " 0.04G", "GHI_w/m2": "223", "created_time": "2024-03-11T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.363", "longitude": "148.06", "air_temperature_celcius": "11", "relative_humidity": "35.3", "windspeed_knots": "18.2", "max_wind_speed": "25.1", "precipitation ": " 0.00I", "GHI_w/m2": "106", "created_time": "2024-03-12T00:00:00", "producer": "producer1"}
# Message published successfully. Data: {"latitude": "-37.8387", "longitude": "144.6301", "air_temperature_celcius": "11", "relative_humidity": "41.4", "windspeed_knots": "7.7", "max_wind_speed": "15", "precipitation ": " 0.03G", "GHI_w/m2": "101", "created_time": "2024-03-13T00:00:00", "producer": "producer1"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 86
#      84 #key = producer1
#      85 publish_message(producer, topic, "producer1", json.dumps(random_data))
# ---> 86 sleep(10)
#
# KeyboardInterrupt:
